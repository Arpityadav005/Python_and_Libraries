# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df.dtypes[df.dtypes != 'object'].index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include = 'object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df[0:100:5]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 5             6         0       3
# 10           11         1       3
# 15           16         1       2
# 20           21         0       2
# 25           26         1       3
# 30           31         0       1
# 35           36         0       1
# 40           41         0       3
# 45           46         0       3
# 50           51         0       3
# 55           56         1       1
# 60           61         0       3
# 65           66         1       3
# 70           71         0       2
# 75           76         0       3
# 80           81         0       3
# 85           86         1       3
# 90           91         0       3
# 95           96         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 5                                    Moran, Mr. James    male   NaN      0
# ...

# %%
df['new_col'] = "Monjolika"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Even_Numbers'] = np.arange(0, len(df) * 2, 2)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# find all the name which as mr. in it
df[df["Name"].str.contains("Mr.")]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#How many Names starts with Rice
df[df["Name"].str.startswith("Rice")]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 16            17         0       3                   Rice, Master Eugene
# 171          172         0       3                   Rice, Master Arthur
# 278          279         0       3                     Rice, Master Eric
# 787          788         0       3              Rice, Master George Hugh
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
#
#         Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked    new_col  \
# 16     male   2.0      4      1  382652  29.125   NaN        Q  Monjolika
# 171    male   4.0      4      1  382652  29.125   NaN        Q  Monjolika
# 278    male   7.0      4      1  382652  29.125   NaN        Q  Monjolika
# 787    male   8.0      4      1  382652  29.125   NaN        Q  Monjolika
# 885  female  39.0      0      5  382652  29.125   NaN        Q  Monjolika
#
#      Even_Numbers
# 16             32
# 171           342
# 278           556
# ...

# %%
#end with..
df[df["Name"].str.endswith("Patrick")]
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 116          117         0       3      Connors, Mr. Patrick  male  70.5
# 510          511         1       3  Daly, Mr. Eugene Patrick  male  29.0
# 517          518         0       3         Ryan, Mr. Patrick  male   NaN
# 890          891         0       3       Dooley, Mr. Patrick  male  32.0
#
#      SibSp  Parch  Ticket   Fare Cabin Embarked    new_col  Even_Numbers
# 116      0      0  370369   7.75   NaN        Q  Monjolika           232
# 510      0      0  382651   7.75   NaN        Q  Monjolika          1020
# 517      0      0  371110  24.15   NaN        Q  Monjolika          1034
# 890      0      0  370376   7.75   NaN        Q  Monjolika          1780

# %%
# give me the name whoes age is Less than 7
df[df['Age'] < 7]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3            Palsson, Master Gosta Leonard
# 10            11         1       3           Sandstrom, Miss Marguerite Rut
# 16            17         0       3                      Rice, Master Eugene
# 43            44         1       2  Laroche, Miss Simonne Marie Anne Andree
# 58            59         1       2              West, Miss Constance Mirium
# 63            64         0       3                     Skoog, Master Harald
# 78            79         1       2             Caldwell, Master Alden Gates
# 119          120         0       3         Andersson, Miss Ellis Anna Maria
# 164          165         0       3              Panula, Master Eino Viljami
# 171          172         0       3                      Rice, Master Arthur
# 172          173         1       3              Johnson, Miss Eleanor Ileen
# ...

# %%
# how many females paid more than average fair
df[(df['Sex'] == 'female') & df['Fare'].mean()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Applications/anaconda/anaconda3/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
#make a new column if fare < 10 them flag the value Low_fare, more than equal to 10 less then 15 then medium and more than this hight fare

# %%
df['Fare_Category'] = np.where(df['Fare'] < 10, 'Low_fare', 
                      np.where(df['Fare'] < 15, 'Medium_fare', 'High_fare'))

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# *************Imp
df['Fare_Category'] = pd.cut(df['Fare'], bins=[0, 10, 15, float('inf')], labels=['Low_fare', 'Medium_fare', 'High_fare'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#df >> iloc..
df.iloc[0:2,]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked    new_col  Even_Numbers  \
# 0      0  A/5 21171   7.2500   NaN        S  Monjolika             0
# 1      0   PC 17599  71.2833   C85        C  Monjolika             2
#
#   Fare_Category
# 0      Low_fare
# 1     High_fare

# %%
df.loc[0:2,['Name']]
# Out:
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                              Heikkinen, Miss Laina

# %%
df_alt = df.iloc[::2, ::2]  
df_alt
# Out:
#      PassengerId  Pclass     Sex  SibSp            Ticket Cabin    new_col  \
# 0              1       3    male      1         A/5 21171   NaN  Monjolika
# 2              3       3  female      0  STON/O2. 3101282   NaN  Monjolika
# 4              5       3    male      0            373450   NaN  Monjolika
# 6              7       1    male      0             17463   E46  Monjolika
# 8              9       3  female      0            347742   NaN  Monjolika
# ..           ...     ...     ...    ...               ...   ...        ...
# 882          883       3  female      0              7552   NaN  Monjolika
# 884          885       3    male      0   SOTON/OQ 392076   NaN  Monjolika
# 886          887       2    male      0            211536   NaN  Monjolika
# 888          889       3  female      1        W./C. 6607   NaN  Monjolika
# 890          891       3    male      0            370376   NaN  Monjolika
#
#     Fare_Category
# 0        Low_fare
# 2        Low_fare
# ...

# %%
df.iloc[::2, ::2]
# Out:
#      PassengerId  Pclass     Sex  SibSp            Ticket Cabin    new_col  \
# 0              1       3    male      1         A/5 21171   NaN  Monjolika
# 2              3       3  female      0  STON/O2. 3101282   NaN  Monjolika
# 4              5       3    male      0            373450   NaN  Monjolika
# 6              7       1    male      0             17463   E46  Monjolika
# 8              9       3  female      0            347742   NaN  Monjolika
# ..           ...     ...     ...    ...               ...   ...        ...
# 882          883       3  female      0              7552   NaN  Monjolika
# 884          885       3    male      0   SOTON/OQ 392076   NaN  Monjolika
# 886          887       2    male      0            211536   NaN  Monjolika
# 888          889       3  female      1        W./C. 6607   NaN  Monjolika
# 890          891       3    male      0            370376   NaN  Monjolika
#
#     Fare_Category
# 0        Low_fare
# 2        Low_fare
# ...

# %%
df.isna().sum()
# Out:
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age              177
# SibSp              0
# Parch              0
# Ticket             0
# Fare               0
# Cabin            687
# Embarked           2
# new_col            0
# Even_Numbers       0
# Fare_Category     15
# dtype: int64

# %%
per = (df.isna().sum() / len(df)) * 100
per
# Out:
# PassengerId       0.000000
# Survived          0.000000
# Pclass            0.000000
# Name              0.000000
# Sex               0.000000
# Age              19.865320
# SibSp             0.000000
# Parch             0.000000
# Ticket            0.000000
# Fare              0.000000
# Cabin            77.104377
# Embarked          0.224467
# new_col           0.000000
# Even_Numbers      0.000000
# Fare_Category     1.683502
# dtype: float64

# %%
df.Age.fillna(0)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     0.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.Cabin.fillna(df.Cabin.mode())
# Out:
# 0      B96 B98
# 1          C85
# 2           G6
# 3         C123
# 4          NaN
#         ...
# 886        NaN
# 887        B42
# 888        NaN
# 889       C148
# 890        NaN
# Name: Cabin, Length: 891, dtype: object

# %%
#groupby # important....
#Average fare for who survived and who did not arvive
df.groupby('Survived')['Fare'].mean()
# Out:
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64

# %%
df.groupby('Survived').mean(numeric_only = True)
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare  \
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408
#
#           Even_Numbers
# Survived
# 0           892.032787
# 1           886.736842

# %%
df.head().T
# Out:
#                                      0  \
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# new_col                      Monjolika
# Even_Numbers                         0
# Fare_Category                 Low_fare
#
#                                                                1  \
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# ...

# %%
df[["Name","Sex","Age"]][0:5]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                              Heikkinen, Miss Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.title.nunique()
# Out:
# 8807

# %%
#how many movies nad TV shoes are there?
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df[df["type"] == "Movie"]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df.type.value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
#which year had most content added to netflix
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#what are top 10 most common genre movie?
df['listed_in'].str.split(', ').explode().value_counts().head(10)
# Out:
# listed_in
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
df['cast'].str.split(', ').explode().value_counts().idxmax()
# Out:
# 'Anupam Kher'
